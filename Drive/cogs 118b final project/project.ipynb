# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("eduardo4jesus/stanford-cars-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/eduardo4jesus/stanford-cars-dataset?dataset_version_number=1...
# 100%|██████████| 1.82G/1.82G [00:31<00:00, 61.9MB/s]
# Extracting files...
# Path to dataset files: C:\Users\jtake\.cache\kagglehub\datasets\eduardo4jesus\stanford-cars-dataset\versions\1

# %%
import pandas as pd

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

train_dir = os.path.join(path, "cars_train")

# list a few filenames
images = os.listdir(train_dir)
print(images[:10])
# Out:
# ['cars_train']

# %%
import random

plt.figure(figsize=(12, 8))
samples = random.sample(images, 9)

for i, fname in enumerate(samples):
    img = Image.open(os.path.join(train_dir, fname))
    plt.subplot(3, 3, i+1)
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 import random
#       3 plt.figure(figsize=(12, 8))
# ----> 4 samples = random.sample(images, 9)
#       6 for i, fname in enumerate(samples):
#       7     img = Image.open(os.path.join(train_dir, fname))
#
# File c:\Users\jtake\anaconda3\envs\cogs118a\Lib\random.py:434, in Random.sample(self, population, k, counts)
#     432 randbelow = self._randbelow
#     433 if not 0 <= k <= n:
# --> 434     raise ValueError("Sample larger than population or is negative")
#     435 result = [None] * k
#     436 setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative
